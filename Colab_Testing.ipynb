# %% [markdown]
# <a href="https://colab.research.google.com/github/Elemode451/collaborationrepo/blob/main/Colab_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')


#Import Numpy and Pandas libraries. 
#Numpy adds support for large, multi-dimensinal arrays and matrics, mathematical functions.
#Pandas is a library for manipulating numerical tables and time series
#seaborn is aPython data visualization library based on matplotlib
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/iris.csv")

df.head()
df.info()
# Out:
# Mounted at /content/drive
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
res = sns.scatterplot(data = df, x = "SepalLength", y = "SepalWidth", hue = "Class")
# pd.set_option('float_format', '{:.2f}'.format)
# display(df[df['Class'] == 'Iris-setosa'].describe())

# %%
print("hello world!")
# Out:
# hello world!

# %%
# Summary stats of all numeric columns
pd.set_option('float_format', '{:.2f}'.format)
df.describe ()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count       150.00      150.00       150.00      150.00
# mean          5.84        3.05         3.76        1.20
# std           0.83        0.43         1.76        0.76
# min           4.30        2.00         1.00        0.10
# 25%           5.10        2.80         1.60        0.30
# 50%           5.80        3.00         4.35        1.30
# 75%           6.40        3.30         5.10        1.80
# max           7.90        4.40         6.90        2.50

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.set_theme(style="whitegrid")
gf=sns.scatterplot(data = df, x = "PetalWidth", y = "PetalLength", hue = "Class")
import matplotlib.pyplot as plt
# for legend text
gf.legend(fontsize=5)
plt.xlabel("PetalWidth", size=16)
plt.ylabel("PetalLength", size=16)
plt.title("PetalWidth vs. PetalLength", size=24)
# Out:
# Text(0.5, 1.0, 'PetalWidth vs. PetalLength')

# %%
sns.pairplot(
    df, hue="Class",
    corner=True,
    diag_kind="hist",
    diag_kws = {'bins': 5}

)

# %%
sl = sns.histplot(df, x = "SepalLength", hue="Class",  kde = True)

# %%
sw = sns.histplot(df, x = "SepalWidth", hue="Class", kde = True)

# %%
pl = sns.histplot(df, x = "PetalLength", hue="Class", kde = True)

# %%
pw = sns.histplot(df, x = "PetalWidth", hue="Class", kde = True)

# %%
classes = ["SepalLength", "SepalWidth", "PetalLength", "PetalWidth"];
for b in classes:
  display(sns.histplot(df, x = b, hue="Class",  kde = True, binwidth = 0.1))
  print("")

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
t = np.arange(0, 6.4, 0.1) #time
f = 1 #frequency
amplitudes = np.arange(-10,11, 1)
A = [x * np.cos(f*t) for x in amplitudes] #amplitude
colormap_sect = np.linspace(0, 1, len(amplitudes))
colors = [cm.cool(x) for x in colormap_sect]
plt.rcParams['figure.figsize'] = [6, 4]
plt.style.use("cyberpunk")
plt.xlim(right=6.3)
for i in range(len(A)):
  plt.plot(t, A[i], color=colors[i])
  mplcyberpunk.make_lines_glow()
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-4fb98e38fe2a> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 from matplotlib import cm
# ----> 4 import mplcyberpunk
#       5 t = np.arange(0, 6.4, 0.1) #time
#       6 f = 1 #frequency
#
# ModuleNotFoundError: No module named 'mplcyberpunk'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
sns.boxplot(data = df, y = "SepalLength", x = "Class", hue = "Class")

# %%
sns.boxplot(data = df, y = "SepalWidth", x = "Class", hue = "Class")

# %%
sns.boxplot(data = df, y = "PetalWidth", x = "Class", hue = "Class")

# %%
sns.boxplot(data = df, y = "PetalLength", x = "Class", hue = "Class")
sns.violinplot(data = df, y = "PetalLength", x = "Class", hue = "Class")
